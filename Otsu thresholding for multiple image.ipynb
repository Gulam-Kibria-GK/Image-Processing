# %% [markdown]
# # Otsu thresholding

# %%
import cv2        
import os
import glob
import numpy as np
from matplotlib import pyplot as plt

# %%
img_dir = "data" # Enter Directory of all images 
data_path = os.path.join(img_dir,'*.*')
files = glob.glob(data_path)
data = []
for f1 in files:
    img = cv2.imread(f1)
    data.append(img)
len(data)
# Out:
# 52

# %% [markdown]
# ## Syntax: cv2.threshold(source, thresholdValue, maxVal, thresholdingTechnique)
#
# ### Parameters:
# ### -> source: Input Image array (must be in Grayscale).
# ### -> thresholdValue: Value of Threshold below and above which pixel values will change accordingly.
# ### -> maxVal: Maximum value that can be assigned to a pixel.
# ### -> thresholdingTechnique: The type of thresholding to be applied.

# %%
def Otsu_thresholding(img1):
    img = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
    ret, thresh1 = cv2.threshold(img, 120, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    return ret,thresh1

# %%
def Original_plot(image2):
        plt.subplot(3,1,1)
        plt.imshow(image2,cmap = 'gray')
        plt.title('Original Noisy Image')
        plt.xticks([]), plt.yticks([])
def Otsu_plot(thresh1): 
        plt.subplot(3,1,3)
        plt.imshow(thresh1,cmap = 'gray')
        plt.title('Otsu thresholding')
        plt.xticks([]), plt.yticks([])
        plt.show()

# %%
def show_both(thresh1,image2):
    cv2.imshow('Original Img',image2)
    cv2.imshow('Otsu Threshold', thresh1)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %% [markdown]
# https://opencv-python-tutroals.readthedocs.io/en/latest/py_tutorials/py_gui/py_image_display/py_image_display.html

# %%
j=0
for i in data:
    j+=1
    print("Image ",j,": \n")
    image1 =i
    image2 =i
    ret,thresh1=Otsu_thresholding(image1)
    #for show
    #show_both(thresh1,image2)
            #or
    Original_plot(image2)
    Otsu_plot(thresh1)
# Out:
# Image  1 :
# Image  2 :
# Image  3 :
# Image  4 :
# Image  5 :
# Image  6 :
# Image  7 :
# Image  8 :
# Image  9 :
# Image  10 :
# Image  11 :
# Image  12 :
# Image  13 :
# Image  14 :
# Image  15 :
# Image  16 :
# Image  17 :
# Image  18 :
# Image  19 :
# Image  20 :
# Image  21 :
# Image  22 :
# Image  23 :
# Image  24 :
# Image  25 :
# Image  26 :
# Image  27 :
# Image  28 :
# Image  29 :
# Image  30 :
# Image  31 :
# Image  32 :
# Image  33 :
# Image  34 :
# Image  35 :
# Image  36 :
# Image  37 :
# Image  38 :
# Image  39 :
# Image  40 :
# Image  41 :
# Image  42 :
# Image  43 :
# Image  44 :
# Image  45 :
# Image  46 :
# Image  47 :
# Image  48 :
# Image  49 :
# Image  50 :
# Image  51 :
# Image  52 :
